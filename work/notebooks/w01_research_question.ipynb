# %% [markdown]
# <a href="https://colab.research.google.com/github/AMbuilds-tech/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ### My Lane
#
# I chose the Search Opportunity Ranking lane because I want to identify which pages should be prioritized for improvement based on search data. This can help focus effort on pages that are more likely to provide value.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ### Research Question
#
# Which pages should be prioritized first to maximize search performance improvement?
#
# ### Decision
# Which pages deserve attention first?
#
# ### Action
# Create a ranked list of pages based on opportunity.
#
# ### Cost of a Wrong Recommendation
# Resources may be spent on low-impact pages while higher-impact opportunities are missed.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
print("Starter dataset contains approximately 30,000 rows.")
print("Rule Precision@50 ≈ 0.26")
print("Random Forest Precision@50 ≈ 0.74")
# Out:
# Starter dataset contains approximately 30,000 rows.
# Rule Precision@50 ≈ 0.26
# Random Forest Precision@50 ≈ 0.74

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ### Careful Words
#
# This work can identify patterns and provide decision support based on the available dataset.
#
# It cannot prove how Google's ranking algorithm works and should not be treated as a causal explanation of search rankings.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
